# %% [markdown]
# <a href="https://colab.research.google.com/github/katarapusrivasthav/My_Python/blob/master/c%20PROGRAMMING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#include<stdio.h>
int main()
{
	int n;
	printf("enter the value of n\n");
	scanf("%d",&n);
	if((n%3==0)&&(n%5==0))
	printf("yes");
	else
	printf("No");
	return 0;
}

# %%
#include<stdio.h>
int main()
{
char x;
scanf("%c",&x);
if((x>=65)&&(x<=90))
{
	printf("Uppercase");
}
else if((x>=97)&&(x<=122))
{
	printf("Lower case");
}
else if((x>=48)&&(x>=57))
{
	printf("Digit");
}
return 0;
}

# %%
#include<stdio.h>
int main()
{
	char x;
	scanf("%c",&x);
	if(x=='a'||x=='e'||x=='i'||x=='o'||x=='u'||x=='A'||x=='E'||x=='I'||x=='O'||x=='U')
	{
	printf("vowels");
	}
	else
	{
	printf("Consonants");
  }
 return 0;
}

# %%
#include<stdio.h>
int main()
{
	int n;
	scanf("%d",&n);
	switch(n)
	{
		case 1: printf("Sunday"); break;
		case 2: printf("Monday"); break;
		case 3: printf("Tuesday"); break;
		case 4: printf("wednesday"); break;
		case 5: printf("Thursday"); break;
		case 6: printf("Friday"); break;
		case 7: printf("Saturday"); break;
		default: printf("Error");
	}
	
}

# %%
#include<stdio.h>
int main()
{
char x;
scanf("%c",&x);
switch(x)
{
	case 'a':printf("vowel"); break;
	case 'e':printf("vowel"); break;
	case 'i':printf("vowel"); break;
	case 'o':printf("vowel"); break;
	case 'u':printf("vowel"); break;
	case 'A':printf("vowel"); break;
	case 'E':printf("vowel"); break;
	case 'I':printf("vowel"); break;
	case 'O':printf("vowel"); break;
	case 'U':printf("vowel"); break;
	default : printf("Consonant");
}


	
}

# %%
#include<stdio.h>
int main()
{
	int a,b,c,x;
	scanf("%d%d%d",&a,&b,&c);
	if((a>b)&&(a>c))
	{
		x=b*c;
	}
	else if((b>a)&&(b>c))
	{
		x=a*c;
	}
	else if((c>a)&&(c>b))
	{
		x=a*b;
		}
		printf("%d",x);
		return 0;	
}

# %%
while(boolean)
{
    loop statements
 increment/decrement
}

# %%
#include<stdio.h>
int main()
{
	int x,y;
	scanf("%d",&x);
	while(x!=0)
	{
	y=x%10;
	printf("%d\t",y);
	x=x/10;
    }
	
return 0;
}

# %%
#include<stdio.h>
int main()
{
	 
	 int a,n,large=0;
	
    scanf("%d",&a);
    while(a!=0)
    {
    n=a%10;
    if(n>large)
    {
	
       large=n;
   }
    
	a=a/10;
}
	printf("%d\n",large);

	
	
	return 0;
}

# %%
#include<stdio.h>
int main()
{
	 
	 int a,n,large=0,i;
	
    scanf("%d",&a);
    for(i=0;i<3;i++)
    
    
    {
    n=a%10;
    if(n>large)
    {
	
       large=n;
   }
    
	a=a/10;
}
	printf("%d\n",large);

	
	
	return 0;
}

# %%
#include<stdio.h>
int main()
{
	 
	 int a,n,large=0,c=0;
	
    scanf("%d",&a);
    while(c!=3)
    
    
    {
    n=a%10;
    if(n>large)
    {
	
       large=n;
   }
   c++;
    
	a=a/10;
}
	printf("%d\n",large);

	
	
	return 0;
}

# %%
#include<stdio.h>
int main()
{
	 
	 int a,n,large=0,small=9;
	
    scanf("%d",&a);
    while(a!=0)
    {
    n=a%10;
    if(n>large)
    {
	
       large=n;
   }
   if(n<small)
   {
   	small=n;
   }
    
	a=a/10;
}
	printf("<%d,%d>",large,small);

	
	
	return 0;
}

# %%
#include<stdio.h>
int main()
{
	int a,t;
	scanf("%d",&a);
	while(a!=0)
	{
	t=a%10;
	a=a/10;
	switch(t)
	{
		case 1:printf("one "); break;
		case 2:printf("two "); break;
		case 3:printf("three "); break;
		case 4:printf("four "); break;
		case 5:printf("five "); break;
		case 6:printf("six "); break;
		case 7:printf("seven "); break;
				case 8:printf("Eight "); break;
				case 9:printf("nine "); break;
				case 0:printf("Zero "); break;
		}	
	}
	return 0;
}

# %%
#include<stdio.h>
int main()
{
	int a,x,s;
	scanf("%d",&a);
	while(a!=0)
	{
	
	x=a%10;
	if(x%2==0)
	{
	s=s+x;	
	}
	a=a/10;
}
printf("%d",s);
return 0;
}

# %%
#include<stdio.h>
int main()
{
	int x,i=1;
	scanf("%d",&x);
    while(i<=x)
    {
    	if(x%i==0)
		{
			printf("%d\t",i);
			}
			i++;	
			}
	return 0;
}

# %%
#include<stdio.h>
int main()
{
	int a,x,s=0;
	scanf("%d",&a);
	while(a!=0)
	{
	
	x=a%10;
	a=a/10;
	switch(x)
	{
		case 1: x=0; break;
		case 2: x=0; break;
		case 3: x=0; break;
		case 4: x=1; break;
		case 5: x=0; break;
		case 6: x=1; break;
		case 7: x=0; break;
		case 8: x=2; break;
		case 9: x=1; break;
		case 0: x=1; break;
		
		
	}
	s=s+x;
}

printf("%d",s);
return 0;
}

# %%
#include<stdio.h>
int main()
{
	int x,temp,n,sum=0;
	scanf("%d",&x);
	temp=x;
	while(x!=0)
	{
		n=x%10;
		sum=(sum*10)+n;
		x=x/10;
	}
	if (sum==temp)
	{
		printf("yes");
		
	}
	else
	{
		printf("no");
	}
	return 0;
}

# %%
#include<stdio.h>
int reverse(int n)
{
int t,y;
while(n!=0)
{
t=n%10;
y=(y*10)+t;
n/=10;
}
return y;
}
int isPrime(int n)
{
int c=2,flag=1;
while(c<n)
{
if(n%c==0)
{
flag=0;
break;
}
c++;
}
return flag;
}
int main()
{
int x,rev;
scanf("%d",&x);
rev=reverse(x);
if(isPrime(x)==1&&isPrime(rev))
printf("Yes");
else
printf("No");
return 0;
}

# %%
#include<stdio.h>
int palindrome(int x)
{
	int rev=0,buffer=x;
	while(x!=0)
	{
	rev=(rev*10)+(x%10);
	x/=10;
}
	if(buffer==rev)
	{
		return 1;
	}
	else
	{
		return 0;
	}
}
int main()
{
	int x1,x2,n,i,res,cnt;
    scanf("%d%d",&x1,&x2);
    scanf("%d",&n); 
    for(i=x1;i<=x2;i++)
    {
    	res=palindrome(i);
    	if(res==1)
    	{
    		cnt++;
    		if(cnt==n)
    		{
    			printf("%d",i);
    			break;
			}
		}
	}
    

    return 0;
}

# %%
#include<stdio.h>
int fact(int x);
int factsum(int x)
{
	int t,s=0;
    while(x!=0)
    {
    	t=x%10;
    	s+=fact(t);
    	x=x/10;
	}
	return s;
}
int main()
{
	int x;
    scanf("%d",&x);
    if(factsum(x)==x)
    {printf("yes");}
	else
	{ printf("no"); }
	
    return 0;
}
int fact(int n)
   {
   	int f=1,i;
   	for(i=1;i<=n;i++)
   	f=f*i;
   	return f;
   }

# %%
#include<stdio.h>
int main()
{
	int n,x,i;
    scanf("%d",&n);
    while(n!=0)
    {
        printf("$");
         	x=n%10;
         	for(i=1;i<=x;i++)
         	{
         		printf("*");
			 }
			 printf("\n");
    	n=n/10;
    	
	}
return 0;

}

# %%
#include<stdio.h>
#include<math.h>
int power(int x);
int digitcount(int x)
{ 
int c=0;
  while(x!=0)
  {
  	
  	x=x/10;
  	c++;
  }
  return c;
}
int main()
{
	int x,y;
    scanf("%d",&x);
    y=power(x);
    printf("%d",y);
     return 0;
}
int power(int x)
{
	int sum=0,c,t;
	c=digitcount(x);
    while(x!=0)
    {
    	t=x%10;
    	sum=sum+pow(t,c);
    	x/=10;
	}
   return sum;
}

# %%
#include<stdio.h>
int main()
{
    int x,a[200],i;
 scanf("%d",x);
 for(i=0;i<x;i++)
{
    scanf("%d",&a[i]);
}
 for(i=0;i<x;i++)
{
    printf("%d",&a[i]);
}
 return 0;
}

# %%
#include<stdio.h>
int main()
{
	int x,i,a[100],L,S;
    scanf("%d",&x);
    for(i=0;i<x;i++)
    {
    	scanf("%d",&a[i]);
    
	}
	L=S=a[0];
	for(i=0;i<x;i++)
	{
	
      if(L<a[i])
      L=a[i];
      if(S>a[i])
      S=a[i];
  }
  printf("<%d,%d>",L,S);
   return 0;
}

# %%
#include<stdio.h>
int main()
{ 
   int x,a[100],i,c=0;
 scanf("%d",&x);
   while(x!=0)
   {
   	a[c]=x%10;
   	x=x/10;
   	c++;
   }
  for(i=c-1;i>=0;i--)
  {
  printf("%d ",a[i]);
  }
  return 0;
}
